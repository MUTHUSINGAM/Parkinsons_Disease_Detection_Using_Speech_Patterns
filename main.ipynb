# %%
import os
import librosa
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import collections

# Function to extract features (MFCC, Chroma, Mel Spectrogram, Spectral Contrast)
def extract_features(file_path, max_pad_length=100):
    y, sr = librosa.load(file_path, sr=22050)
    
    
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    mel = librosa.feature.melspectrogram(y=y, sr=sr)
    contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
    
    # Flatten and concatenate all features
    features = np.concatenate([mfcc.flatten(), chroma.flatten(), mel.flatten(), contrast.flatten()])
    
    # Ensure consistent feature length
    pad_width = max_pad_length - features.shape[0]
    if pad_width > 0:
        features = np.pad(features, (0, pad_width), mode='constant')
    else:
        features = features[:max_pad_length]  # Trim to fixed length
    
    return features


data_dirs = {
    "healthy": r"E:\dverse\singam\healthy\healthy_in",  # Update with correct paths
    "parkinson": r"E:\dverse\singam\parkinson\parkinson_in"
}

# Load the dataset
data = []
labels = []

for label, directory in data_dirs.items():
    for file in os.listdir(directory):
        file_path = os.path.join(directory, file)
        try:
            feature = extract_features(file_path)
            data.append(feature)
            labels.append(label)
        except Exception as e:
            print(f"Error processing {file}: {e}")

# Convert to numpy arrays
data = np.array(data)
labels = np.array(labels)

# Check dataset balance
print("Dataset Distribution:", collections.Counter(labels))

# Encode labels
encoder = LabelEncoder()
labels = encoder.fit_transform(labels)  # 0 = Healthy, 1 = Parkinson

# Normalize features
scaler = StandardScaler()
data = scaler.fit_transform(data)

# Split dataset (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define an improved neural network model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(data.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy', metrics=['accuracy'])

# Train the model 
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# Function to predict new audio samples
def predict_audio(file_path):
    feature = extract_features(file_path).reshape(1, -1)
    feature = scaler.transform(feature)  
    prediction = model.predict(feature)
    return "Parkinson Present" if prediction > 0.5 else "Healthy"

# Example usage (predict on a new audio file)
new_audio = r"E:\dverse\singam\parkinson\parkinson_in\AH_264Z_593C20CD-0A54-4177-B031-26EE147080A3.wav"
print(predict_audio(new_audio))
# Out:
# Dataset Distribution: Counter({'parkinson': 41, 'healthy': 40})
# Epoch 1/100
# c:\Users\MUTHUSINGAM N\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 222ms/step - accuracy: 0.4271 - loss: 0.9672 - val_accuracy: 0.5294 - val_loss: 0.6849
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5521 - loss: 0.6864 - val_accuracy: 0.7059 - val_loss: 0.6167
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7083 - loss: 0.5832 - val_accuracy: 0.7059 - val_loss: 0.5802
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7812 - loss: 0.4421 - val_accuracy: 0.7059 - val_loss: 0.5564
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8021 - loss: 0.3876 - val_accuracy: 0.7647 - val_loss: 0.5378
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8021 - loss: 0.4145 - val_accuracy: 0.7647 - val_loss: 0.5272
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8021 - loss: 0.4304 - val_accuracy: 0.7647 - val_loss: 0.5193
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7917 - loss: 0.3893 - val_accuracy: 0.7647 - val_loss: 0.5132
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8854 - loss: 0.3199 - val_accuracy: 0.7647 - val_loss: 0.5095
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8125 - loss: 0.3715 - val_accuracy: 0.7647 - val_loss: 0.5070
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8958 - loss: 0.2567 - val_accuracy: 0.7647 - val_loss: 0.5057
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8958 - loss: 0.2655 - val_accuracy: 0.7647 - val_loss: 0.5047
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8958 - loss: 0.2442 - val_accuracy: 0.7647 - val_loss: 0.5037
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.
100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9896 - loss: 0.0321 - val_accuracy: 0.5882 - val_loss: 0.7801
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 0.5882 - val_loss: 0.8018
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0226 - val_accuracy: 0.5882 - val_loss: 0.8184
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 0.5882 - val_loss: 0.8392
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.5294 - val_loss: 0.8502
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0254 - val_accuracy: 0.5882 - val_loss: 0.8534
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9792 - loss: 0.0427 - val_accuracy: 0.5882 - val_loss: 0.8380
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0324 - val_accuracy: 0.6471 - val_loss: 0.8144
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9792 - loss: 0.0475 - val_accuracy: 0.6471 - val_loss: 0.7825
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9792 - loss: 0.0381 - val_accuracy: 0.6471 - val_loss: 0.7610
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9792 - loss: 0.0490 - val_accuracy: 0.6471 - val_loss: 0.7450
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9896 - loss: 0.0208 - val_accuracy: 0.7059 - val_loss: 0.7402
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0185 - val_accuracy: 0.7059 - val_loss: 0.7426
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.7059 - val_loss: 0.7484
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0587 - val_accuracy: 0.7059 - val_loss: 0.7545
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 0.6471 - val_loss: 0.7714
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9792 - loss: 0.0344 - val_accuracy: 0.6471 - val_loss: 0.7898
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.6471 - val_loss: 0.8063
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9896 - loss: 0.0289 - val_accuracy: 0.6471 - val_loss: 0.8229
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0217 - val_accuracy: 0.5882 - val_loss: 0.8373
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.5882 - val_loss: 0.8532
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.5294 - val_loss: 0.8708
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9792 - loss: 0.0613 - val_accuracy: 0.5294 - val_loss: 0.8871
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9479 - loss: 0.1075 - val_accuracy: 0.5294 - val_loss: 0.9132
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9896 - loss: 0.0365 - val_accuracy: 0.5294 - val_loss: 0.9301
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.5294 - val_loss: 0.9472
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.5294 - val_loss: 0.9558
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.5294 - val_loss: 0.9648
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.5294 - val_loss: 0.9668
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.5294 - val_loss: 0.9660
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9792 - loss: 0.0405 - val_accuracy: 0.5294 - val_loss: 0.9922
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9583 - loss: 0.0930 - val_accuracy: 0.5294 - val_loss: 1.0212
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.5294 - val_loss: 1.0518
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0271 - val_accuracy: 0.5294 - val_loss: 1.0737
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.5294 - val_loss: 1.0812
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.5294 - val_loss: 1.0682
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.5294 - val_loss: 1.0600
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.5294 - val_loss: 1.0475
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.5294 - val_loss: 1.0164
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.5294 - val_loss: 0.9889
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0374 - val_accuracy: 0.5294 - val_loss: 0.9863
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.5294 - val_loss: 0.9842
